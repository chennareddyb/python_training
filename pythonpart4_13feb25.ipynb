# %% [markdown]
# <a href="https://colab.research.google.com/github/chennareddyb/python_training/blob/Feb2025/pythonpart4_13feb25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Functions
# def functionName (parameters..):
#   function defination
#
# functionName(parameters...)
#
# **in method paramerts**\
# if we use one * then it is consideted as tuple\
# if we use two ** then it is considered as dictionary

# %%
def additiion(num1, num2):
  result = num1 + num2
  print("Result inside Function: ",result)

print("Before calling Function")
additiion(10,20)
print("After calling Function")
# Out:
# Before calling Function
# Result inside Function:  30
# After calling Function

# %%
#if number of arguments are unknown and it will take in tuple format
def additiion(*num):
  result = 0
  for i in num:
    result = result + i
  print("Result inside Function: ",result)
print("Addition of three number")
additiion(10,20,30)
print("Addition of four number")
additiion(10,20,30,40)
print("Addition of five number")
additiion(10,20,30,40,50)
print("Addition of single number")
additiion(10)
# Out:
# Addition of three number
# Result inside Function:  60
# Addition of four number
# Result inside Function:  100
# Addition of five number
# Result inside Function:  150
# Addition of single number
# Result inside Function:  10

# %%
def empName(*name):
  print("Name of third employee is :", name[2])
empName("chenna","Raju","Suman")
# Out:
# Name of third employee is : Suman

# %%
def empDetails(**emp): #if we want details in dictionary format then we use **
  print("ID of employee",emp["id"])
  print("Name of employee",emp["fname"],emp["lname"])
  print("Employee: ",emp)
empDetails(fname="Raju",lname="singh", id=101)
# Out:
# ID of employee 101
# Name of employee Raju singh
# Employee:  {'fname': 'Raju', 'lname': 'singh', 'id': 101}
