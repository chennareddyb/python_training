# %% [markdown]
# <a href="https://colab.research.google.com/github/chennareddyb/python_training/blob/Feb2025/pythonpart3_11feb25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Set
#
# set wont return duplicates
# Doesnot maintan any order
#
# mySet = {"A","B","C"}
#
# if 1 and True are present in a set, response it will print only one and it will print the first value
# same way if 0 and False are present, in response it will print only one either 0 or False based of first occurrence

# %%
mySet = {"Chenna","Raju","James","Phil","Harry","Raju"}
print(mySet)
# Out:
# {'Phil', 'Chenna', 'James', 'Raju', 'Harry'}

# %%
mySet1 = {"Chenna", 1, True, False, 0, "New york"}
print(mySet1)
print(len(mySet1))
print(type(mySet1))
# Out:
# {False, 1, 'Chenna', 'New york'}
# 4
# <class 'set'>

# %%
for data in mySet :
  print(data)

if "James" in mySet :
  print("Yes it is Available")
# Out:
# Phil
# Chenna
# James
# Raju
# Harry
# Yes it is Available
